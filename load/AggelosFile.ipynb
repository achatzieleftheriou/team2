# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %%
flights = pd.read_csv("C:/Users/AggelosMavraganis/githubproject/team2/csvfile/flight_delays.csv")
flights
# Out:
#          FlightID    Airline  FlightNumber Origin Destination  \
# 0               1     United          4558    ORD         MIA
# 1               2      Delta          8021    LAX         MIA
# 2               3  Southwest          7520    DFW         SFO
# 3               4      Delta          2046    ORD         BOS
# 4               5      Delta          6049    LAX         SEA
# ...           ...        ...           ...    ...         ...
# 1747622   1747623     United          4145    DFW         MIA
# 1747623   1747624     United          2155    ATL         SEA
# 1747624   1747625      Delta          4878    JFK         SFO
# 1747625   1747626      Delta          2940    JFK         SEA
# 1747626   1747627     United          1319    LAX         MIA
#
#         ScheduledDeparture   ActualDeparture  ScheduledArrival  \
# 0         2024-09-01 08:11  2024-09-01 08:30  2024-09-01 12:11
# 1         2024-09-01 10:25  2024-09-01 10:41  2024-09-01 13:25
# 2         2024-09-01 16:53  2024-09-01 17:05  2024-09-01 17:53
# 3         2024-09-01 14:44  2024-09-01 15:04  2024-09-01 18:44
# 4         2024-09-01 01:51  2024-09-01 02:08  2024-09-01 05:51
# ...                    ...               ...               ...
# 1747622   2024-09-01 12:46  2024-09-01 12:54  2024-09-01 17:46
# 1747623   2024-09-01 20:43  2024-09-01 20:54  2024-09-01 21:43
# 1747624   2024-09-01 03:26  2024-09-01 03:47  2024-09-01 06:26
# 1747625   2024-09-01 08:04  2024-09-01 08:07  2024-09-01 13:04
# 1747626   2024-09-01 12:46  2024-09-01 13:11  2024-09-01 15:46
#
#             ActualArrival  DelayMinutes          DelayReason  Cancelled  \
# 0        2024-09-01 12:19             8              Weather       True
# 1        2024-09-01 13:27             2  Air Traffic Control       True
# 2        2024-09-01 18:07            14              Weather       True
# 3        2024-09-01 18:34           -10                  NaN      False
# 4        2024-09-01 06:15            24  Air Traffic Control      False
# ...                   ...           ...                  ...        ...
# 1747622  2024-09-01 17:41            -5                  NaN      False
# 1747623  2024-09-01 22:03            20              Weather       True
# 1747624  2024-09-01 06:20            -6                  NaN      False
# 1747625  2024-09-01 13:20            16          Maintenance      False
# 1747626  2024-09-01 16:05            19          Maintenance       True
#
#          Diverted AircraftType TailNumber  Distance
# 0           False   Boeing 737     N71066      1031
# 1            True  Airbus A320     N22657      1006
# 2            True   Boeing 737     N95611      2980
# 3           False   Boeing 777     N90029      1408
# 4            True   Boeing 737     N27417      2298
# ...           ...          ...        ...       ...
# 1747622      True   Boeing 737     N19796      2396
# 1747623     False   Boeing 777     N68154      2185
# 1747624     False   Boeing 777     N18964       361
# 1747625      True  Airbus A320     N94591      2793
# 1747626      True   Boeing 737     N76065      1501
#
# [1747627 rows x 16 columns]

# %%
flights.describe()
# Out:
#            FlightID  FlightNumber  DelayMinutes      Distance
# count  1.747627e+06  1.747627e+06  1.747627e+06  1.747627e+06
# mean   8.738140e+05  5.001158e+03  9.999179e+00  1.549936e+03
# std    5.044966e+05  2.885822e+03  1.183112e+01  8.368681e+02
# min    1.000000e+00  1.000000e+00 -1.000000e+01  1.000000e+02
# 25%    4.369075e+05  2.503000e+03  0.000000e+00  8.250000e+02
# 50%    8.738140e+05  5.002000e+03  1.000000e+01  1.551000e+03
# 75%    1.310720e+06  7.499000e+03  2.000000e+01  2.274000e+03
# max    1.747627e+06  9.999000e+03  3.000000e+01  3.000000e+03

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747627 entries, 0 to 1747626
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   FlightID            int64
#  1   Airline             object
#  2   FlightNumber        int64
#  3   Origin              object
#  4   Destination         object
#  5   ScheduledDeparture  object
#  6   ActualDeparture     object
#  7   ScheduledArrival    object
#  8   ActualArrival       object
#  9   DelayMinutes        int64
#  10  DelayReason         object
#  11  Cancelled           bool
#  12  Diverted            bool
#  13  AircraftType        object
#  14  TailNumber          object
#  15  Distance            int64
# dtypes: bool(2), int64(4), object(10)
# memory usage: 190.0+ MB

# %%
flights.isnull().sum()
# Out:
# FlightID                   0
# Airline                    0
# FlightNumber               0
# Origin                     0
# Destination                0
# ScheduledDeparture         0
# ActualDeparture            0
# ScheduledArrival           0
# ActualArrival              0
# DelayMinutes               0
# DelayReason           468873
# Cancelled                  0
# Diverted                   0
# AircraftType               0
# TailNumber                 0
# Distance                   0
# dtype: int64

# %%
flights.fillna("No Delay Reason", inplace=True)

# %%
flights.head(100)
# Out:
#     FlightID            Airline  FlightNumber Origin Destination  \
# 0          1             United          4558    ORD         MIA
# 1          2              Delta          8021    LAX         MIA
# 2          3          Southwest          7520    DFW         SFO
# 3          4              Delta          2046    ORD         BOS
# 4          5              Delta          6049    LAX         SEA
# ..       ...                ...           ...    ...         ...
# 95        96              Delta          8531    JFK         BOS
# 96        97  American Airlines          1655    ATL         SFO
# 97        98             United          8925    ATL         JFK
# 98        99              Delta          5930    LAX         SEA
# 99       100  American Airlines          2066    ORD         MIA
#
#    ScheduledDeparture   ActualDeparture  ScheduledArrival     ActualArrival  \
# 0    2024-09-01 08:11  2024-09-01 08:30  2024-09-01 12:11  2024-09-01 12:19
# 1    2024-09-01 10:25  2024-09-01 10:41  2024-09-01 13:25  2024-09-01 13:27
# 2    2024-09-01 16:53  2024-09-01 17:05  2024-09-01 17:53  2024-09-01 18:07
# 3    2024-09-01 14:44  2024-09-01 15:04  2024-09-01 18:44  2024-09-01 18:34
# 4    2024-09-01 01:51  2024-09-01 02:08  2024-09-01 05:51  2024-09-01 06:15
# ..                ...               ...               ...               ...
# 95   2024-09-01 00:35  2024-09-01 00:50  2024-09-01 02:35  2024-09-01 02:49
# 96   2024-09-01 11:57  2024-09-01 12:19  2024-09-01 17:57  2024-09-01 18:25
# 97   2024-09-01 22:50  2024-09-01 22:55  2024-09-02 03:50  2024-09-02 04:09
# 98   2024-09-01 08:47  2024-09-01 08:52  2024-09-01 11:47  2024-09-01 12:08
# 99   2024-09-01 19:42  2024-09-01 19:42  2024-09-01 22:42  2024-09-01 22:33
#
#     DelayMinutes          DelayReason  Cancelled  Diverted AircraftType  \
# 0              8              Weather       True     False   Boeing 737
# 1              2  Air Traffic Control       True      True  Airbus A320
# 2             14              Weather       True      True   Boeing 737
# 3            -10      No Delay Reason      False     False   Boeing 777
# 4             24  Air Traffic Control      False      True   Boeing 737
# ..           ...                  ...        ...       ...          ...
# 95            14  Air Traffic Control       True      True   Boeing 777
# 96            28              Weather       True      True  Airbus A320
# 97            19              Weather       True      True   Boeing 777
# 98            21          Maintenance      False     False   Boeing 777
# 99            -9      No Delay Reason      False      True   Boeing 777
#
#    TailNumber  Distance
# 0      N71066      1031
# 1      N22657      1006
# 2      N95611      2980
# 3      N90029      1408
# 4      N27417      2298
# ..        ...       ...
# 95     N49477       794
# 96     N17550      2948
# 97     N44017      1436
# 98     N70967      2608
# 99     N18308      2977
#
# [100 rows x 16 columns]

# %%
flights['ScheduledDeparture'] = pd.to_datetime(flights['ScheduledDeparture'])
flights['ActualDeparture'] = pd.to_datetime(flights['ActualDeparture'])
flights['ScheduledArrival'] = pd.to_datetime(flights['ScheduledArrival'])
flights['ActualArrival'] = pd.to_datetime(flights['ActualArrival'])

# %%
flights.head(5)
# Out:
#    FlightID    Airline  FlightNumber Origin Destination  ScheduledDeparture  \
# 0         1     United          4558    ORD         MIA 2024-09-01 08:11:00
# 1         2      Delta          8021    LAX         MIA 2024-09-01 10:25:00
# 2         3  Southwest          7520    DFW         SFO 2024-09-01 16:53:00
# 3         4      Delta          2046    ORD         BOS 2024-09-01 14:44:00
# 4         5      Delta          6049    LAX         SEA 2024-09-01 01:51:00
#
#       ActualDeparture    ScheduledArrival       ActualArrival  DelayMinutes  \
# 0 2024-09-01 08:30:00 2024-09-01 12:11:00 2024-09-01 12:19:00             8
# 1 2024-09-01 10:41:00 2024-09-01 13:25:00 2024-09-01 13:27:00             2
# 2 2024-09-01 17:05:00 2024-09-01 17:53:00 2024-09-01 18:07:00            14
# 3 2024-09-01 15:04:00 2024-09-01 18:44:00 2024-09-01 18:34:00           -10
# 4 2024-09-01 02:08:00 2024-09-01 05:51:00 2024-09-01 06:15:00            24
#
#            DelayReason  Cancelled  Diverted AircraftType TailNumber  Distance
# 0              Weather       True     False   Boeing 737     N71066      1031
# 1  Air Traffic Control       True      True  Airbus A320     N22657      1006
# 2              Weather       True      True   Boeing 737     N95611      2980
# 3      No Delay Reason      False     False   Boeing 777     N90029      1408
# 4  Air Traffic Control      False      True   Boeing 737     N27417      2298

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747627 entries, 0 to 1747626
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   FlightID            int64
#  1   Airline             object
#  2   FlightNumber        int64
#  3   Origin              object
#  4   Destination         object
#  5   ScheduledDeparture  datetime64[ns]
#  6   ActualDeparture     datetime64[ns]
#  7   ScheduledArrival    datetime64[ns]
#  8   ActualArrival       datetime64[ns]
#  9   DelayMinutes        int64
#  10  DelayReason         object
#  11  Cancelled           bool
#  12  Diverted            bool
#  13  AircraftType        object
#  14  TailNumber          object
#  15  Distance            int64
# dtypes: bool(2), datetime64[ns](4), int64(4), object(6)
# memory usage: 190.0+ MB

# %%
flights["DepartureDiff"]= flights['ScheduledDeparture'] - flights['ActualDeparture']

# %%
flights.head()
# Out:
#    FlightID    Airline  FlightNumber Origin Destination  ScheduledDeparture  \
# 0         1     United          4558    ORD         MIA 2024-09-01 08:11:00
# 1         2      Delta          8021    LAX         MIA 2024-09-01 10:25:00
# 2         3  Southwest          7520    DFW         SFO 2024-09-01 16:53:00
# 3         4      Delta          2046    ORD         BOS 2024-09-01 14:44:00
# 4         5      Delta          6049    LAX         SEA 2024-09-01 01:51:00
#
#       ActualDeparture    ScheduledArrival       ActualArrival  DelayMinutes  \
# 0 2024-09-01 08:30:00 2024-09-01 12:11:00 2024-09-01 12:19:00             8
# 1 2024-09-01 10:41:00 2024-09-01 13:25:00 2024-09-01 13:27:00             2
# 2 2024-09-01 17:05:00 2024-09-01 17:53:00 2024-09-01 18:07:00            14
# 3 2024-09-01 15:04:00 2024-09-01 18:44:00 2024-09-01 18:34:00           -10
# 4 2024-09-01 02:08:00 2024-09-01 05:51:00 2024-09-01 06:15:00            24
#
#            DelayReason  Cancelled  Diverted AircraftType TailNumber  Distance  \
# 0              Weather       True     False   Boeing 737     N71066      1031
# 1  Air Traffic Control       True      True  Airbus A320     N22657      1006
# 2              Weather       True      True   Boeing 737     N95611      2980
# 3      No Delay Reason      False     False   Boeing 777     N90029      1408
# 4  Air Traffic Control      False      True   Boeing 737     N27417      2298
#
#       DepartureDiff
# 0 -1 days +23:41:00
# 1 -1 days +23:44:00
# 2 -1 days +23:48:00
# 3 -1 days +23:40:00
# 4 -1 days +23:43:00
